# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
FileName = 'C:\\Dd\\Share Price data for Assignment regarding Manipulation.csv'
SP = pd.read_csv(FileName, skiprows=2, index_col = 0) #
df = pd.DataFrame(SP)
df
# Out:
#             09:30  10:30  11:30  12:30  13:30  14:30  15:30
# Date
# 13th April  20.38  20.82  22.66  22.17  20.69  22.19  22.73
# 14th April  18.51  19.52  21.01  20.00  19.04  19.02  25.48
# 15th April  22.87  25.99  24.25  25.71  21.91  21.19  23.51
# 16th April  23.71  24.03  18.52  22.14  20.63  19.17  25.35
# 17th April  25.37  22.06  23.44  21.63  23.95  24.78  24.06
# 18th April  20.87  22.99  21.25  24.71  23.91  23.19  21.51
# 19th April  19.00  23.79  24.53  23.95  24.41  22.74  22.37
# 20th April  22.17  24.99  23.25  22.71  24.91  23.19  22.51

# %%
df.plot(kind = 'line', figsize = (25,15), title = 'Hourly Traded Share Prices - Single View',
          xlabel = 'Days', ylabel  = 'Values')
# Out:
# <AxesSubplot:title={'center':'Hourly Traded Share Prices - Single View'}, xlabel='Days', ylabel='Values'>

# %%
df.plot(kind = 'bar', figsize = (25,15), title = 'Hourly Traded Share Prices - Single View',
          xlabel = 'Days', ylabel  = 'Values')
# Out:
# <AxesSubplot:title={'center':'Hourly Traded Share Prices - Single View'}, xlabel='Days', ylabel='Values'>

# %% [raw]
# plt.subplots?
